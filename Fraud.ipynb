# %% [markdown]
# # Importing Libraries and our dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing our dataset from the desired location
#Creating the dataframe
df=pd.read_csv("project1.csv")

# %%
#displaying the information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
# step              int64
# type              object
# amount            float64
# nameOrig          object
# oldbalanceOrg     float64
# newbalanceOrig    float64
# nameDest          object
# oldbalanceDest    float64
# newbalanceDest    float64
# isFraud           int64
# isFlaggedFraud    int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
df.describe()
# Out:
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  6.362620e+06  6.362620e+06   6.362620e+06    6.362620e+06
# mean   2.433972e+02  1.798619e+05   8.338831e+05    8.551137e+05
# std    1.423320e+02  6.038582e+05   2.888243e+06    2.924049e+06
# min    1.000000e+00  0.000000e+00   0.000000e+00    0.000000e+00
# 25%    1.560000e+02  1.338957e+04   0.000000e+00    0.000000e+00
# 50%    2.390000e+02  7.487194e+04   1.420800e+04    0.000000e+00
# 75%    3.350000e+02  2.087215e+05   1.073152e+05    1.442584e+05
# max    7.430000e+02  9.244552e+07   5.958504e+07    4.958504e+07
#
#        oldbalanceDest  newbalanceDest       isFraud  isFlaggedFraud
# count    6.362620e+06    6.362620e+06  6.362620e+06    6.362620e+06
# mean     1.100702e+06    1.224996e+06  1.290820e-03    2.514687e-06
# std      3.399180e+06    3.674129e+06  3.590480e-02    1.585775e-03
# min      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# 25%      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# 50%      1.327057e+05    2.146614e+05  0.000000e+00    0.000000e+00
# 75%      9.430367e+05    1.111909e+06  0.000000e+00    0.000000e+00
# max      3.560159e+08    3.561793e+08  1.000000e+00    1.000000e+00

# %%
# displaying the first five records of our dataset
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %% [markdown]
# # EDA

# %%
# displaying the heat-map of correlation among each columns.
sns.heatmap(df.corr())

# %%
# checking whether there is any null value or not and displaying the respective heatmap
sns.heatmap(df.isnull())

# %%
#displaying the pairplots
sns.pairplot(data=df,hue='isFraud')

# %%
#calculating number of fraud transfers
dfFraudTransfer = df.loc[(df.isFraud == 1) & (df.type == 'TRANSFER')]
len(dfFraudTransfer)
# Out:
# 4097

# %%
#calculating number of frauds in cash_out
dfFraudCashout = df.loc[(df.isFraud == 1) & (df.type == 'CASH_OUT')]
len(dfFraudCashout)
# Out:
# 4116

# %%
#caculating number of number of transfers which are greater than 2,00,000
df[df['isFlaggedFraud']==1].count()['isFlaggedFraud']
# Out:
# 16

# %%
#dispalying maximum amunt of a non fraud user
df[df['isFlaggedFraud']==0].max()['amount']
# Out:
# 92445516.64

# %%
#drop it because wrong(since transfered amount is greater than 2,00,000 so flagged fraud)

# %%
df[df['isFlaggedFraud']==1].min()['amount']
# Out:
# 353874.22

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
tmp = df.loc[(df.type == 'TRANSFER'), :]

a = sns.boxplot(x = 'isFlaggedFraud', y = 'amount', data = tmp, ax=axs[0][0])
axs[0][0].set_yscale('log')
b = sns.boxplot(x = 'isFlaggedFraud', y = 'oldbalanceDest', data = tmp, ax=axs[0][1])
axs[0][1].set(ylim=(0, 0.5e8))
c = sns.boxplot(x = 'isFlaggedFraud', y = 'oldbalanceOrg', data=tmp, ax=axs[1][0])
axs[1][0].set(ylim=(0, 3e7))
d = sns.regplot(x = 'oldbalanceOrg', y = 'amount', data=tmp.loc[(tmp.isFlaggedFraud ==1), :], ax=axs[1][1])
plt.show()

# %% [markdown]
# It can be easily seen that transactions with *isFlaggedFraud*
# set occur at
# all values of *step*, similar to the complementary set of transactions. Thus
# *isFlaggedFraud* does not correlate with *step* either and is therefore
# seemingly unrelated to any explanatory variable or feature in the data

# %% [markdown]
# *Conclusion*: Although *isFraud* is always set when *isFlaggedFraud* is set, since
# *isFlaggedFraud* is set just 16 times in a seemingly meaningless way, we
# can treat this feature as insignificant and discard it in the dataset
# without loosing information.

# %%
#checking the names starting with 'M'
def func(s):
    for i in s:
        if(i=='M'):
            return True
        else:
            return False

# %%
#calculating the number of users starting with "M" under the transaction 'CASH_IN'
df.loc[df.type == 'CASH_IN'].nameOrig.apply(func).value_counts()
# Out:
# False    1399284
# Name: nameOrig, dtype: int64

# %%
#calculating the number of users starting with "M" under the transaction 'PAYMENT'
df.loc[df.type == 'PAYMENT'].nameOrig.apply(func).value_counts()
# Out:
# False    2151495
# Name: nameOrig, dtype: int64

# %%
df.loc[df.type == 'PAYMENT'].nameDest.apply(func).value_counts()
# Out:
# True    2151495
# Name: nameDest, dtype: int64

# %%
#There are same no. of users who are making transaction 'PAYMENT' and who are recieving 'PAYMENT'and name starts with 'M'

# %%
#displaying the factor plots
sns.factorplot(x="type",col='isFraud',data = df,kind ='count',size=7,aspect=.7)

# %%
#counting total no. of entries in 'isFraud' column
q=df.count()['isFraud']
#Finding no.transactions where amount is not 0,both new and old balance of destination is 0 but when it is not fraud
p=len(df.loc[(df.oldbalanceDest == 0) & (df.newbalanceDest == 0) & (df.amount) & (df.isFraud == 0)])
#calculating fractions of such above transactions
print((p/q)*100)
#Finding no. of transactions where both new and old balance of destination account is 0 and it is actually a fraud one
r=len(df.loc[(df.oldbalanceDest == 0) & (df.newbalanceDest == 0) & (df.amount) & (df.isFraud == 1)])
#calculating the fraction of such above transactions
print((r/q)*100)
# Out:
# 36.35618660237449
# 0.06396735935825179

# %% [markdown]
# # Data Cleaning

# %%
#We have analysed that fraud transaction exists only for 'TRANSFER' and 'CASH_OUT'
#Creating a new dataset containing only transfer and cash-outs
X = df.loc[(df['type'] == 'TRANSFER') | (df['type'] == 'CASH_OUT')]

# %%
#displaying the first 5 data of x
X.head()
# Out:
#     step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2      1  TRANSFER     181.00  C1305486145          181.0             0.0
# 3      1  CASH_OUT     181.00   C840083671          181.0             0.0
# 15     1  CASH_OUT  229133.94   C905080434        15325.0             0.0
# 19     1  TRANSFER  215310.30  C1670993182          705.0             0.0
# 24     1  TRANSFER  311685.89  C1984094095        10835.0             0.0
#
#        nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 2    C553264065             0.0            0.00        1               0
# 3     C38997010         21182.0            0.00        1               0
# 15   C476402209          5083.0        51513.44        0               0
# 19  C1100439041         22425.0            0.00        0               0
# 24   C932583850          6267.0      2719172.89        0               0

# %%
X.reset_index(inplace=True,drop=True)

# %%
X.head()
# Out:
#    step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1  TRANSFER     181.00  C1305486145          181.0             0.0
# 1     1  CASH_OUT     181.00   C840083671          181.0             0.0
# 2     1  CASH_OUT  229133.94   C905080434        15325.0             0.0
# 3     1  TRANSFER  215310.30  C1670993182          705.0             0.0
# 4     1  TRANSFER  311685.89  C1984094095        10835.0             0.0
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0   C553264065             0.0            0.00        1               0
# 1    C38997010         21182.0            0.00        1               0
# 2   C476402209          5083.0        51513.44        0               0
# 3  C1100439041         22425.0            0.00        0               0
# 4   C932583850          6267.0      2719172.89        0               0

# %%
# Eliminate columns shown to be irrelevant for analysis in the EDA
X.drop(['nameOrig', 'nameDest', 'isFlaggedFraud','step'], axis = 1,inplace=True)
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\pandas\core\frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
X.head()
# Out:
#        type     amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0  TRANSFER     181.00          181.0             0.0             0.0
# 1  CASH_OUT     181.00          181.0             0.0         21182.0
# 2  CASH_OUT  229133.94        15325.0             0.0          5083.0
# 3  TRANSFER  215310.30          705.0             0.0         22425.0
# 4  TRANSFER  311685.89        10835.0             0.0          6267.0
#
#    newbalanceDest  isFraud
# 0            0.00        1
# 1            0.00        1
# 2        51513.44        0
# 3            0.00        0
# 4      2719172.89        0

# %%
X.columns
# Out:
# Index(['type', 'amount', 'oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest',
#        'newbalanceDest', 'isFraud'],
#       dtype='object')

# %%
#converting the categorial values into binary values for the column 'Type'
typee = pd.get_dummies(X['type'],drop_first=True)
#storing the new dataset in 'NewData' after concatinating the 'type' column
NewData = pd.concat([X,typee],axis=1)
# dropping the 'type' column as we don't need the categorical values any more, rather the binary ones.
NewData.drop(['type'],inplace=True,axis=1)

# %%
# displaying the first 5 values of the new dataset
NewData.head()
# Out:
#       amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  newbalanceDest  \
# 0     181.00          181.0             0.0             0.0            0.00
# 1     181.00          181.0             0.0         21182.0            0.00
# 2  229133.94        15325.0             0.0          5083.0        51513.44
# 3  215310.30          705.0             0.0         22425.0            0.00
# 4  311685.89        10835.0             0.0          6267.0      2719172.89
#
#    isFraud  TRANSFER
# 0        1         1
# 1        1         0
# 2        0         0
# 3        0         1
# 4        0         1

# %%
#displaying the heat map of correlation
sns.heatmap(NewData.corr(),annot=True,cmap='viridis')

# %% [markdown]
# # Under-Sampling

# %%
# dispalying the countplot
sns.countplot(x='isFraud',data=NewData)

# %%
#from the countplot we observe that dataset is imbalanced
#Hence we move on to balance the datasets.
#calculating the number of fraud transactions in our new concatenated datasets
frauds = len(NewData[NewData['isFraud'] == 1])
#Storing the corresponding to the fraud transactions indices
fraud_indices = NewData[NewData.isFraud == 1].index
#Storing corresponding to the non fraud transactions indices
non_fraud_indices = NewData[NewData.isFraud == 0].index

# %%
#calculating the number of non fraud transactions
non_frauds = len(NewData[NewData['isFraud'] == 0])
#we randomly choose from non-fraud-indices, such that its number equals with no. of fraud ones
np.random.seed(0)
random_indices = np.random.choice(non_fraud_indices,frauds, replace=False)
len(random_indices)
# Out:
# 8213

# %%
#random indices and fraud indices are concatenated and we obtain the indices we require for our new balanced dataset
under_sample_indices = np.concatenate([random_indices,fraud_indices],axis =0)
len(under_sample_indices)
# Out:
# 16426

# %%
#Obtaining the new final balanced data-set using the indices obtained in the previous dataset
under_sample = NewData.loc[under_sample_indices]
under_sample.reset_index(inplace=True,drop=True)
under_sample.head()
# Out:
#        amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  newbalanceDest  \
# 0   200978.67         6592.0             0.0            0.00       200978.67
# 1   133246.97            0.0             0.0       288141.15       421388.12
# 2  2875864.54        15011.0             0.0            0.00      2875864.54
# 3   293331.60            0.0             0.0       491315.07       784646.67
# 4   201668.50            0.0             0.0      2025944.19      2227612.69
#
#    isFraud  TRANSFER
# 0        0         0
# 1        0         0
# 2        0         1
# 3        0         0
# 4        0         0

# %%
#calculating the number of non fraud transactions in under sampled datset
under_sample[under_sample['isFraud']==0].count()
# Out:
# amount            8213
# oldbalanceOrg     8213
# newbalanceOrig    8213
# oldbalanceDest    8213
# newbalanceDest    8213
# isFraud           8213
# TRANSFER          8213
# dtype: int64

# %%
#displaying the countplot
sns.countplot(x='isFraud',data=under_sample)

# %%
#contrary to the previous counter plots both the frauds and the non-frauds cover equal area under the curves

# %%
#displaying the heatmap of correlation
sns.heatmap(under_sample.corr(),annot=True)

# %%
#Joint-plot of 'amount' vs. 'isFraud'
sns.jointplot(x='amount',y='isFraud',data=under_sample)
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\DELL\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.lmplot(x='oldbalanceOrg',y='isFraud',data=under_sample)

# %% [markdown]
# # Training our Model

# %%
#choosing our dependent and independent variables, respectively
y = under_sample['isFraud']
x = under_sample[['amount', 'oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest',
       'newbalanceDest','TRANSFER']]

# %%
from sklearn.model_selection import train_test_split

# %%
#Choosing training data to be 30% and rest as our testing data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=101)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
#creating object for linear regression
lm = LinearRegression()

# %%
#providing training data to create the machine
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#printing the intercept of the best fit curve
print(lm.intercept_)
# Out:
# 0.33482982673660033

# %%
#printing the coefficients
lm.coef_
# Out:
# array([-1.77265039e-07,  2.49017655e-07, -2.61097832e-07, -4.23396557e-08,
#         4.03081530e-08,  3.47677654e-01])

# %%
#the trained machine predicts the corresponding y-values of the given test datas 
pred = lm.predict(x_test)
pred
# Out:
# array([0.30846832, 0.48498503, 0.68003985, ..., 0.58553905, 0.34916305,
#        0.32622449])

# %%
#the predicted values should be either 0 or 1

# %%
#a scatterd plot to check the error of predicted values against actual values
plt.scatter(y_test,pred)
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.show()

# %%
#making distribution plot of our error
sns.distplot((y_test-pred),kde=True)
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
 #we have created a distribution plot considering the error in predicted values.
#It is observed that the Gausean Plot is not proper.
#Hence,Linear Regression is not applicable here beacuse it is applicable for clustering problem.

# %%
from sklearn import metrics

# %%
#calculating the absollute error
metrics.mean_absolute_error(y_test,pred)
# Out:
# 0.38608982351905435

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
#creating object for logistic regression
lr_under = LogisticRegression()

# %%
#providing datas to train the machine 
lr_under.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
#storing the predicted values
y_under_pred = lr_under.predict(x_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
#printing the classification report 
print(classification_report(y_test,y_under_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.97      0.88      0.92      2484
#           1       0.89      0.97      0.93      2444
#
# avg / total       0.93      0.93      0.93      4928

# %%
#we find model accuracy to be 93%. Hence we can accept the model.

# %%
#printing the confusion matrix 
print(confusion_matrix(y_test,y_under_pred))
# Out:
# [[2189  295]
#  [  72 2372]]

# %%
#Cross-validation of our model
from sklearn.model_selection import cross_val_score
accuracies=cross_val_score(estimator=lr_under,X=x_train,y=y_train)
accuracies.mean()
# Out:
# 0.916941969720159

# %%
from sklearn.metrics import roc_curve

# %%
fpr, tpr,_=roc_curve(y_under_pred,y_test,drop_intermediate=False)

# %%
plt.figure()

# %%
#plotting the ROC curve
plt.plot(fpr, tpr, color='red',
 lw=2, label='ROC curve')

##Random FPR and TPR
plt.plot([0, 1], [0, 1], color='blue', lw=2, linestyle='--',label = 'Normal Curve')
##Title and label
plt.xlabel('False Posative')
plt.ylabel('True Posative')
plt.title('ROC curve')
plt.legend()
plt.show()

# %%
#Finding the area under ROC curve
from sklearn.metrics import auc
metrics.auc(fpr,tpr)
# Out:
# 0.9287722548613311

# %% [markdown]
# # K-NN Algorithm

# %%
from sklearn.preprocessing import StandardScaler

# %%
#creating standardscalar
scalar = StandardScaler()

# %%
#scaling the dataset o make the mean 0 and standard deviation 1
scalar.fit(x)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaled_features = scalar.transform(x)

# %%
#creating a new dataset after transforming the old data set
df_feat = pd.DataFrame(scaled_features,columns = x.columns)

# %%
df_feat.head()
# Out:
#      amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  newbalanceDest  \
# 0 -0.363990      -0.318615       -0.074574       -0.276949       -0.320205
# 1 -0.399606      -0.321117       -0.074574       -0.206708       -0.272394
# 2  1.042561      -0.315421       -0.074574       -0.276949        0.260028
# 3 -0.315427      -0.321117       -0.074574       -0.157180       -0.193596
# 4 -0.363627      -0.321117       -0.074574        0.216919        0.119410
#
#    TRANSFER
# 0 -0.730062
# 1 -0.730062
# 2  1.369746
# 3 -0.730062
# 4 -0.730062

# %%
# Defining of dependent and independent variables,respectively
x1=df_feat[['amount', 'oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest','newbalanceDest', 'TRANSFER']]
y1=under_sample['isFraud']

# %%
#30% of the data is used for testing and remaining 705 is used for training
x1_train, x1_test, y1_train, y1_test = train_test_split(x1, y1, test_size=0.3, random_state=101)

# %%
from sklearn.neighbors import KNeighborsClassifier
#creating object with 1 neighbour hence predicting the results
Knn=KNeighborsClassifier(n_neighbors=1)
Knn.fit(x1_train,y1_train)
pred=Knn.predict(x1_test)
pred
# Out:
# array([0, 1, 0, ..., 1, 1, 0], dtype=int64)

# %%
#printing the confuusion matrix
print(confusion_matrix(y1_test,pred))
# Out:
# [[2390   94]
#  [  86 2358]]

# %%
#printing the classification report
print(classification_report(y1_test,pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.97      0.96      0.96      2484
#           1       0.96      0.96      0.96      2444
#
# avg / total       0.96      0.96      0.96      4928

# %%
#we find that our knn model is 96% accurate. Hence it can be accepted.

# %%
#caclculating the error rate for different values of 'n-neighbours'
error_rate=[]
for i in range(1,30):
    Knn=KNeighborsClassifier(n_neighbors=i)
    Knn.fit(x1_train,y1_train)
    pred_i=Knn.predict(x1_test)
    error_rate.append(np.mean(pred_i!=y1_test))
plt.figure(figsize=(10,6))
plt.plot(range(1,30),error_rate,linestyle='dashed',marker='o',markersize=10)

# %%
# the graph shows that knn has least error when number of neighbours selected is 1 which we have already selected

# %%
#Performing cross-validation on our selected model
from sklearn.model_selection import cross_val_score
accuracies=cross_val_score(estimator=Knn,X=x1_train,y=y1_train)
accuracies.mean()
# Out:
# 0.9328575317704852

# %%
fpr1, tpr1,_=roc_curve(pred,y1_test,drop_intermediate=False)
plt.figure()

# %%
#plotting the ROC curve
plt.plot(fpr1, tpr1, color='red',
 lw=2, label='ROC curve')

##Random FPR and TPR
plt.plot([0, 1], [0, 1], color='blue', lw=2, linestyle='--')
##Title and label
plt.xlabel('False Posative')
plt.ylabel('True Posative')
plt.title('ROC curve')
plt.show()

# %%
#Finding area under ROC curve
metrics.auc(fpr1,tpr1)
# Out:
# 0.9634652533818951

# %% [markdown]
# # Decision_trees

# %%
from sklearn.tree import DecisionTreeClassifier
#creating object and providing training data
dtree=DecisionTreeClassifier()
dtree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
#Predicting frim our model
pre=dtree.predict(x_test)
#displaying the classification report and confusion matrix
print(confusion_matrix(y_test,pre))
print(classification_report(y_test,pre))
# Out:
# [[2457   27]
#  [  32 2412]]
#              precision    recall  f1-score   support
#
#           0       0.99      0.99      0.99      2484
#           1       0.99      0.99      0.99      2444
#
# avg / total       0.99      0.99      0.99      4928

# %%
#We find that our accuracy is quite high, to be 99%. we further cross-validate our model.

# %%
#Cross-validation of our model
from sklearn.model_selection import cross_val_score
accuracies=cross_val_score(estimator=dtree,X=x_train,y=y_train,cv=10)
accuracies.mean()
# Out:
# 0.9840845326465686

# %%
fpr1, tpr1,_=roc_curve(pre,y_test,drop_intermediate=False)
plt.figure()

# %%
#plotting the ROC curve
plt.plot(fpr1, tpr1, color='red',
 lw=2, label='ROC curve')

##Random FPR and TPR
plt.plot([0, 1], [0, 1], color='blue', lw=2, linestyle='--')
##Title and label
plt.xlabel('False Posative')
plt.ylabel('True Posative')
plt.title('ROC curve')
plt.show()

# %%
#Finding area under ROC curve
metrics.auc(fpr1,tpr1)
# Out:
# 0.9880366601978594

# %% [markdown]
# # Random_Forest_Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
#creating an object for random forest having 1000 as parameter for n_estimators
rfc=RandomForestClassifier(n_estimators=1000)
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
#prediction using this model
rfc_pred=rfc.predict(x_test)
#displaying the confusion matrix and classification report 
print(confusion_matrix(y_test,rfc_pred))
print(classification_report(y_test,rfc_pred))
# Out:
# [[2442   42]
#  [  12 2432]]
#              precision    recall  f1-score   support
#
#           0       1.00      0.98      0.99      2484
#           1       0.98      1.00      0.99      2444
#
# avg / total       0.99      0.99      0.99      4928

# %%
#we find that our model has 99% accuracy
#cross-validation of our model
from sklearn.model_selection import cross_val_score
accuracies=cross_val_score(estimator=rfc,X=x_train,y=y_train,cv=10)
accuracies.mean()
# Out:
# 0.9866061202848053

# %%
fpr1, tpr1,_=roc_curve(rfc_pred,y_test,drop_intermediate=False)
plt.figure()

# %%
#plotting the ROC curve
plt.plot(fpr1, tpr1, color='red',
 lw=2, label='ROC curve')

##Random FPR and TPR
plt.plot([0, 1], [0, 1], color='blue', lw=2, linestyle='--')
##Title and label
plt.xlabel('False Posative')
plt.ylabel('True Posative')
plt.title('ROC curve')
plt.show()

# %%
#Finding area under ROC curve
metrics.auc(fpr1,tpr1)
# Out:
# 0.9890667341327805

# %% [markdown]
# # Gaussian_Naive_classifier

# %%
from sklearn.naive_bayes import GaussianNB
#creating an object
model=GaussianNB()
#providing data to train the machine 
model.fit(x_train,y_train)
predicted=model.predict(x_test)
#displaying the predicted values after prediction
print(predicted)
# Out:
# [0 1 0 ... 1 0 0]

# %%
#printing the confusion matrix and classification report
print(confusion_matrix(y_test,predicted))
print(classification_report(y_test,predicted))
# Out:
# [[2425   59]
#  [1255 1189]]
#              precision    recall  f1-score   support
#
#           0       0.66      0.98      0.79      2484
#           1       0.95      0.49      0.64      2444
#
# avg / total       0.80      0.73      0.72      4928

# %%
#Cross-Validation of our model
from sklearn.model_selection import cross_val_score
accuracies=cross_val_score(estimator=model,X=x_train,y=y_train)
accuracies.mean()
# Out:
# 0.7214288716401045

# %%
fpr1, tpr1,_=roc_curve(predicted,y_test,drop_intermediate=False)
plt.figure()

# %%
#plotting the ROC curve
plt.plot(fpr1, tpr1, color='red',
 lw=2, label='ROC curve')

##Random FPR and TPR
plt.plot([0, 1], [0, 1], color='blue', lw=2, linestyle='--')
##Title and label
plt.xlabel('False Posative')
plt.ylabel('True Posative')
plt.title('ROC curve')
plt.show()

# %%
#Calculating the area under above ROC curve 
metrics.auc(fpr1,tpr1)
# Out:
# 0.8058458751393535

# %%
#we find from our classification report, our accuracy is 80% and our cross validation score is approx 0.72
#As, both are quite less we don't prefer this model.

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVC

# %%
#Creating SVM object
model = SVC()

# %%
#Training of model
model.fit(x_train,y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
#Prediction using SVM
pred = model.predict(x_test)

# %%
#Confusion matrix display
print(confusion_matrix(y_test,pred))
# Out:
# [[2484    0]
#  [2400   44]]

# %%
#Classification report of our SVM model
print(classification_report(y_test,pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.51      1.00      0.67      2484
#           1       1.00      0.02      0.04      2444
#
# avg / total       0.75      0.51      0.36      4928

# %%
#Cross-validation of our SVM model
from sklearn.model_selection import cross_val_score
accuracies=cross_val_score(estimator=model,X=x_train,y=y_train)
accuracies.mean()
# Out:
# 0.5060011572214412

# %%
#We try to improve our SVM model by using GridSearhCV

# %%
from sklearn.grid_search import GridSearchCV
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
param_grid = {'C':[0.1,1,10,100,1000],'gamma':[1,0.1,0.01,0.001,0.0001]}

# %%
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=3)

# %%
#Training the model using grid search
grid.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ......................... C=0.1, gamma=1, score=0.501696 -   5.6s
# [CV] C=0.1, gamma=1 ..................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    5.6s remaining:    0.0s
# [CV] ......................... C=0.1, gamma=1, score=0.501696 -   5.4s
# [CV] C=0.1, gamma=1 ..................................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   11.0s remaining:    0.0s
# [CV] ......................... C=0.1, gamma=1, score=0.501827 -   5.9s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ....................... C=0.1, gamma=0.1, score=0.501696 -   5.4s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ....................... C=0.1, gamma=0.1, score=0.501696 -   5.3s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ....................... C=0.1, gamma=0.1, score=0.501827 -   5.4s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ...................... C=0.1, gamma=0.01, score=0.501696 -   5.4s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ...................... C=0.1, gamma=0.01, score=0.501696 -   5.4s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ...................... C=0.1, gamma=0.01, score=0.501827 -   5.4s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] ..................... C=0.1, gamma=0.001, score=0.501696 -   5.4s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] ..................... C=0.1, gamma=0.001, score=0.501696 -   5.4s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] ..................... C=0.1, gamma=0.001, score=0.501827 -   5.4s
# [CV] C=0.1, gamma=0.0001 .............................................
# [CV] .................... C=0.1, gamma=0.0001, score=0.501696 -   5.4s
# [CV] C=0.1, gamma=0.0001 .............................................
# [CV] .................... C=0.1, gamma=0.0001, score=0.501696 -   5.4s
# [CV] C=0.1, gamma=0.0001 .............................................
# [CV] .................... C=0.1, gamma=0.0001, score=0.501827 -   5.4s
# [CV] C=1, gamma=1 ....................................................
# [CV] ........................... C=1, gamma=1, score=0.503261 -   6.0s
# [CV] C=1, gamma=1 ....................................................
# [CV] ........................... C=1, gamma=1, score=0.502739 -   6.1s
# [CV] C=1, gamma=1 ....................................................
# [CV] ........................... C=1, gamma=1, score=0.501827 -   6.1s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ......................... C=1, gamma=0.1, score=0.506392 -   6.3s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ......................... C=1, gamma=0.1, score=0.506392 -   7.9s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ......................... C=1, gamma=0.1, score=0.508090 -   6.5s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........................ C=1, gamma=0.01, score=0.514740 -   6.4s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........................ C=1, gamma=0.01, score=0.514480 -   7.1s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........................ C=1, gamma=0.01, score=0.515919 -   6.5s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....................... C=1, gamma=0.001, score=0.538482 -   6.6s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....................... C=1, gamma=0.001, score=0.532481 -   6.7s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....................... C=1, gamma=0.001, score=0.541754 -   6.7s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ...................... C=1, gamma=0.0001, score=0.576311 -   6.8s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ...................... C=1, gamma=0.0001, score=0.571354 -   7.3s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ...................... C=1, gamma=0.0001, score=0.579071 -   7.2s
# [CV] C=10, gamma=1 ...................................................
# [CV] .......................... C=10, gamma=1, score=0.503261 -   8.1s
# [CV] C=10, gamma=1 ...................................................
# [CV] .......................... C=10, gamma=1, score=0.503000 -   8.2s
# [CV] C=10, gamma=1 ...................................................
# [CV] .......................... C=10, gamma=1, score=0.501827 -   6.0s
# [CV] C=10, gamma=0.1 .................................................
# [CV] ........................ C=10, gamma=0.1, score=0.507175 -   8.4s
# [CV] C=10, gamma=0.1 .................................................
# [CV] ........................ C=10, gamma=0.1, score=0.507175 -   7.9s
# [CV] C=10, gamma=0.1 .................................................
# [CV] ........................ C=10, gamma=0.1, score=0.508090 -   8.3s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....................... C=10, gamma=0.01, score=0.516306 -   9.3s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....................... C=10, gamma=0.01, score=0.515262 -   8.9s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....................... C=10, gamma=0.01, score=0.516180 -   9.3s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...................... C=10, gamma=0.001, score=0.541351 -  10.3s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...................... C=10, gamma=0.001, score=0.535612 -  10.3s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...................... C=10, gamma=0.001, score=0.544102 -  10.3s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] ..................... C=10, gamma=0.0001, score=0.579703 -  10.2s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] ..................... C=10, gamma=0.0001, score=0.573702 -  12.0s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] ..................... C=10, gamma=0.0001, score=0.583246 -  10.5s
# [CV] C=100, gamma=1 ..................................................
# [CV] ......................... C=100, gamma=1, score=0.503261 -   8.1s
# [CV] C=100, gamma=1 ..................................................
# [CV] ......................... C=100, gamma=1, score=0.503000 -   8.2s
# [CV] C=100, gamma=1 ..................................................
# [CV] ......................... C=100, gamma=1, score=0.501827 -   5.9s
# [CV] C=100, gamma=0.1 ................................................
# [CV] ....................... C=100, gamma=0.1, score=0.507175 -   8.4s
# [CV] C=100, gamma=0.1 ................................................
# [CV] ....................... C=100, gamma=0.1, score=0.507175 -   8.0s
# [CV] C=100, gamma=0.1 ................................................
# [CV] ....................... C=100, gamma=0.1, score=0.508090 -   8.2s
# [CV] C=100, gamma=0.01 ...............................................
# [CV] ...................... C=100, gamma=0.01, score=0.516306 -   9.4s
# [CV] C=100, gamma=0.01 ...............................................
# [CV] ...................... C=100, gamma=0.01, score=0.515262 -   9.1s
# [CV] C=100, gamma=0.01 ...............................................
# [CV] ...................... C=100, gamma=0.01, score=0.516180 -   9.3s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] ..................... C=100, gamma=0.001, score=0.541351 -  10.1s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] ..................... C=100, gamma=0.001, score=0.535612 -  10.2s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] ..................... C=100, gamma=0.001, score=0.544102 -  10.3s
# [CV] C=100, gamma=0.0001 .............................................
# [CV] .................... C=100, gamma=0.0001, score=0.579703 -  10.1s
# [CV] C=100, gamma=0.0001 .............................................
# [CV] .................... C=100, gamma=0.0001, score=0.573702 -  12.0s
# [CV] C=100, gamma=0.0001 .............................................
# [CV] .................... C=100, gamma=0.0001, score=0.583246 -  10.6s
# [CV] C=1000, gamma=1 .................................................
# [CV] ........................ C=1000, gamma=1, score=0.503261 -   8.1s
# [CV] C=1000, gamma=1 .................................................
# [CV] ........................ C=1000, gamma=1, score=0.503000 -   8.2s
# [CV] C=1000, gamma=1 .................................................
# [CV] ........................ C=1000, gamma=1, score=0.501827 -   6.0s
# [CV] C=1000, gamma=0.1 ...............................................
# [CV] ...................... C=1000, gamma=0.1, score=0.507175 -   8.3s
# [CV] C=1000, gamma=0.1 ...............................................
# [CV] ...................... C=1000, gamma=0.1, score=0.507175 -   7.9s
# [CV] C=1000, gamma=0.1 ...............................................
# [CV] ...................... C=1000, gamma=0.1, score=0.508090 -   8.2s
# [CV] C=1000, gamma=0.01 ..............................................
# [CV] ..................... C=1000, gamma=0.01, score=0.516306 -   9.2s
# [CV] C=1000, gamma=0.01 ..............................................
# [CV] ..................... C=1000, gamma=0.01, score=0.515262 -   8.9s
# [CV] C=1000, gamma=0.01 ..............................................
# [CV] ..................... C=1000, gamma=0.01, score=0.516180 -   9.2s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] .................... C=1000, gamma=0.001, score=0.541351 -  10.2s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] .................... C=1000, gamma=0.001, score=0.535612 -  10.2s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] .................... C=1000, gamma=0.001, score=0.544102 -  10.2s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................... C=1000, gamma=0.0001, score=0.579703 -  10.2s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................... C=1000, gamma=0.0001, score=0.573702 -  11.9s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................... C=1000, gamma=0.0001, score=0.583246 -  10.5s
# [Parallel(n_jobs=1)]: Done  75 out of  75 | elapsed: 10.0min finished
# GridSearchCV(cv=None, error_score='raise',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'C': [0.1, 1, 10, 100, 1000], 'gamma': [1, 0.1, 0.01, 0.001, 0.0001]},
#        pre_dispatch='2*n_jobs', refit=True, scoring=None, verbose=3)

# %%
#Finding best parameter for grid_search
grid.best_params_
# Out:
# {'C': 10, 'gamma': 0.0001}

# %%
#Finding best estimator for grid search
grid.best_estimator_
# Out:
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.0001, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
grid_pred=grid.predict(x_test)

# %%
#Displaying of classification report
print(classification_report(y_test,grid_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.56      1.00      0.72      2484
#           1       1.00      0.20      0.33      2444
#
# avg / total       0.78      0.60      0.53      4928

# %%
#Displaying the confusion matrix
print(confusion_matrix(y_test,grid_pred))
# Out:
# [[2484    0]
#  [1956  488]]

# %%
#Cross-validation of our model
from sklearn.model_selection import cross_val_score
accuracies=cross_val_score(estimator=grid,X=x_train,y=y_train)
print(accuracies.mean())
# Out:
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ......................... C=0.1, gamma=1, score=0.501761 -   2.3s
# [CV] C=0.1, gamma=1 ..................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.3s remaining:    0.0s
# [CV] ......................... C=0.1, gamma=1, score=0.501761 -   2.3s
# [CV] C=0.1, gamma=1 ..................................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.8s remaining:    0.0s
# [CV] ......................... C=0.1, gamma=1, score=0.501761 -   2.3s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ....................... C=0.1, gamma=0.1, score=0.501761 -   2.3s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ....................... C=0.1, gamma=0.1, score=0.501761 -   2.3s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ....................... C=0.1, gamma=0.1, score=0.501761 -   2.3s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ...................... C=0.1, gamma=0.01, score=0.501761 -   2.4s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ...................... C=0.1, gamma=0.01, score=0.501761 -   2.4s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ...................... C=0.1, gamma=0.01, score=0.501761 -   2.3s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] ..................... C=0.1, gamma=0.001, score=0.501761 -   2.3s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] ..................... C=0.1, gamma=0.001, score=0.501761 -   2.3s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] ..................... C=0.1, gamma=0.001, score=0.501761 -   2.3s
# [CV] C=0.1, gamma=0.0001 .............................................
# [CV] .................... C=0.1, gamma=0.0001, score=0.501761 -   2.3s
# [CV] C=0.1, gamma=0.0001 .............................................
# [CV] .................... C=0.1, gamma=0.0001, score=0.501761 -   2.3s
# [CV] C=0.1, gamma=0.0001 .............................................
# [CV] .................... C=0.1, gamma=0.0001, score=0.501761 -   2.3s
# [CV] C=1, gamma=1 ....................................................
# [CV] ........................... C=1, gamma=1, score=0.503718 -   2.4s
# [CV] C=1, gamma=1 ....................................................
# [CV] ........................... C=1, gamma=1, score=0.503718 -   2.5s
# [CV] C=1, gamma=1 ....................................................
# [CV] ........................... C=1, gamma=1, score=0.501761 -   2.5s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ......................... C=1, gamma=0.1, score=0.506849 -   2.5s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ......................... C=1, gamma=0.1, score=0.505284 -   2.5s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ......................... C=1, gamma=0.1, score=0.506849 -   2.5s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........................ C=1, gamma=0.01, score=0.513894 -   2.7s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........................ C=1, gamma=0.01, score=0.515460 -   2.8s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........................ C=1, gamma=0.01, score=0.515851 -   2.5s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....................... C=1, gamma=0.001, score=0.529550 -   2.6s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....................... C=1, gamma=0.001, score=0.532290 -   2.6s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....................... C=1, gamma=0.001, score=0.529941 -   2.6s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ...................... C=1, gamma=0.0001, score=0.557730 -   2.8s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ...................... C=1, gamma=0.0001, score=0.562818 -   2.6s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ...................... C=1, gamma=0.0001, score=0.561644 -   2.6s
# [CV] C=10, gamma=1 ...................................................
# [CV] .......................... C=10, gamma=1, score=0.503718 -   2.5s
# [CV] C=10, gamma=1 ...................................................
# [CV] .......................... C=10, gamma=1, score=0.503718 -   2.6s
# [CV] C=10, gamma=1 ...................................................
# [CV] .......................... C=10, gamma=1, score=0.501761 -   2.5s
# [CV] C=10, gamma=0.1 .................................................
# [CV] ........................ C=10, gamma=0.1, score=0.506849 -   2.8s
# [CV] C=10, gamma=0.1 .................................................
# [CV] ........................ C=10, gamma=0.1, score=0.505284 -   2.6s
# [CV] C=10, gamma=0.1 .................................................
# [CV] ........................ C=10, gamma=0.1, score=0.506849 -   2.5s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....................... C=10, gamma=0.01, score=0.513894 -   2.6s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....................... C=10, gamma=0.01, score=0.515460 -   2.7s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....................... C=10, gamma=0.01, score=0.516243 -   2.7s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...................... C=10, gamma=0.001, score=0.532290 -   2.7s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...................... C=10, gamma=0.001, score=0.535029 -   2.6s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...................... C=10, gamma=0.001, score=0.530724 -   2.6s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] ..................... C=10, gamma=0.0001, score=0.560078 -   2.7s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] ..................... C=10, gamma=0.0001, score=0.566341 -   2.7s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] ..................... C=10, gamma=0.0001, score=0.565949 -   2.7s
# [CV] C=100, gamma=1 ..................................................
# [CV] ......................... C=100, gamma=1, score=0.503718 -   2.6s
# [CV] C=100, gamma=1 ..................................................
# [CV] ......................... C=100, gamma=1, score=0.503718 -   2.5s
# [CV] C=100, gamma=1 ..................................................
# [CV] ......................... C=100, gamma=1, score=0.501761 -   2.6s
# [CV] C=100, gamma=0.1 ................................................
# [CV] ....................... C=100, gamma=0.1, score=0.506849 -   2.6s
# [CV] C=100, gamma=0.1 ................................................
# [CV] ....................... C=100, gamma=0.1, score=0.505284 -   2.6s
# [CV] C=100, gamma=0.1 ................................................
# [CV] ....................... C=100, gamma=0.1, score=0.506849 -   2.5s
# [CV] C=100, gamma=0.01 ...............................................
# [CV] ...................... C=100, gamma=0.01, score=0.513894 -   2.7s
# [CV] C=100, gamma=0.01 ...............................................
# [CV] ...................... C=100, gamma=0.01, score=0.515460 -   2.7s
# [CV] C=100, gamma=0.01 ...............................................
# [CV] ...................... C=100, gamma=0.01, score=0.516243 -   2.6s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] ..................... C=100, gamma=0.001, score=0.532290 -   2.6s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] ..................... C=100, gamma=0.001, score=0.535029 -   2.8s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] ..................... C=100, gamma=0.001, score=0.530724 -   2.7s
# [CV] C=100, gamma=0.0001 .............................................
# [CV] .................... C=100, gamma=0.0001, score=0.560078 -   2.8s
# [CV] C=100, gamma=0.0001 .............................................
# [CV] .................... C=100, gamma=0.0001, score=0.566341 -   2.7s
# [CV] C=100, gamma=0.0001 .............................................
# [CV] .................... C=100, gamma=0.0001, score=0.565949 -   2.7s
# [CV] C=1000, gamma=1 .................................................
# [CV] ........................ C=1000, gamma=1, score=0.503718 -   2.5s
# [CV] C=1000, gamma=1 .................................................
# [CV] ........................ C=1000, gamma=1, score=0.503718 -   2.6s
# [CV] C=1000, gamma=1 .................................................
# [CV] ........................ C=1000, gamma=1, score=0.501761 -   2.6s
# [CV] C=1000, gamma=0.1 ...............................................
# [CV] ...................... C=1000, gamma=0.1, score=0.506849 -   2.5s
# [CV] C=1000, gamma=0.1 ...............................................
# [CV] ...................... C=1000, gamma=0.1, score=0.505284 -   2.5s
# [CV] C=1000, gamma=0.1 ...............................................
# [CV] ...................... C=1000, gamma=0.1, score=0.506849 -   2.6s
# [CV] C=1000, gamma=0.01 ..............................................
# [CV] ..................... C=1000, gamma=0.01, score=0.513894 -   2.6s
# [CV] C=1000, gamma=0.01 ..............................................
# [CV] ..................... C=1000, gamma=0.01, score=0.515460 -   2.6s
# [CV] C=1000, gamma=0.01 ..............................................
# [CV] ..................... C=1000, gamma=0.01, score=0.516243 -   2.6s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] .................... C=1000, gamma=0.001, score=0.532290 -   3.0s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] .................... C=1000, gamma=0.001, score=0.535029 -   2.6s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] .................... C=1000, gamma=0.001, score=0.530724 -   2.6s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................... C=1000, gamma=0.0001, score=0.560078 -   2.8s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................... C=1000, gamma=0.0001, score=0.566341 -   2.7s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................... C=1000, gamma=0.0001, score=0.565949 -   2.7s
# [Parallel(n_jobs=1)]: Done  75 out of  75 | elapsed:  3.3min finished
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ......................... C=0.1, gamma=1, score=0.501761 -   2.4s
# [CV] C=0.1, gamma=1 ..................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [CV] ......................... C=0.1, gamma=1, score=0.501761 -   2.3s
# [CV] C=0.1, gamma=1 ..................................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.8s remaining:    0.0s
# [CV] ......................... C=0.1, gamma=1, score=0.501761 -   2.4s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ....................... C=0.1, gamma=0.1, score=0.501761 -   2.7s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ....................... C=0.1, gamma=0.1, score=0.501761 -   2.4s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ....................... C=0.1, gamma=0.1, score=0.501761 -   2.4s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ...................... C=0.1, gamma=0.01, score=0.501761 -   2.4s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ...................... C=0.1, gamma=0.01, score=0.501761 -   2.3s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ...................... C=0.1, gamma=0.01, score=0.501761 -   2.4s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] ..................... C=0.1, gamma=0.001, score=0.501761 -   2.6s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] ..................... C=0.1, gamma=0.001, score=0.501761 -   2.4s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] ..................... C=0.1, gamma=0.001, score=0.501761 -   2.4s
# [CV] C=0.1, gamma=0.0001 .............................................
# [CV] .................... C=0.1, gamma=0.0001, score=0.501761 -   2.4s
# [CV] C=0.1, gamma=0.0001 .............................................
# [CV] .................... C=0.1, gamma=0.0001, score=0.501761 -   2.4s
# [CV] C=0.1, gamma=0.0001 .............................................
# [CV] .................... C=0.1, gamma=0.0001, score=0.501761 -   2.4s
# [CV] C=1, gamma=1 ....................................................
# [CV] ........................... C=1, gamma=1, score=0.502153 -   2.5s
# [CV] C=1, gamma=1 ....................................................
# [CV] ........................... C=1, gamma=1, score=0.504110 -   2.5s
# [CV] C=1, gamma=1 ....................................................
# [CV] ........................... C=1, gamma=1, score=0.504892 -   2.6s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ......................... C=1, gamma=0.1, score=0.504110 -   2.6s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ......................... C=1, gamma=0.1, score=0.504501 -   2.5s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ......................... C=1, gamma=0.1, score=0.506458 -   2.6s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........................ C=1, gamma=0.01, score=0.511546 -   2.8s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........................ C=1, gamma=0.01, score=0.513112 -   2.6s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........................ C=1, gamma=0.01, score=0.515851 -   2.6s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....................... C=1, gamma=0.001, score=0.532290 -   2.6s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....................... C=1, gamma=0.001, score=0.527984 -   2.6s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....................... C=1, gamma=0.001, score=0.536204 -   2.6s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ...................... C=1, gamma=0.0001, score=0.560470 -   2.7s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ...................... C=1, gamma=0.0001, score=0.557730 -   2.6s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ...................... C=1, gamma=0.0001, score=0.563992 -   2.6s
# [CV] C=10, gamma=1 ...................................................
# [CV] .......................... C=10, gamma=1, score=0.502153 -   2.5s
# [CV] C=10, gamma=1 ...................................................
# [CV] .......................... C=10, gamma=1, score=0.504110 -   2.5s
# [CV] C=10, gamma=1 ...................................................
# [CV] .......................... C=10, gamma=1, score=0.504892 -   2.4s
# [CV] C=10, gamma=0.1 .................................................
# [CV] ........................ C=10, gamma=0.1, score=0.504501 -   2.5s
# [CV] C=10, gamma=0.1 .................................................
# [CV] ........................ C=10, gamma=0.1, score=0.504892 -   2.5s
# [CV] C=10, gamma=0.1 .................................................
# [CV] ........................ C=10, gamma=0.1, score=0.506458 -   2.5s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....................... C=10, gamma=0.01, score=0.513112 -   2.6s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....................... C=10, gamma=0.01, score=0.513503 -   2.6s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....................... C=10, gamma=0.01, score=0.517417 -   2.5s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...................... C=10, gamma=0.001, score=0.533855 -   2.7s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...................... C=10, gamma=0.001, score=0.528767 -   2.6s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...................... C=10, gamma=0.001, score=0.538552 -   2.6s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] ..................... C=10, gamma=0.0001, score=0.564775 -   2.7s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] ..................... C=10, gamma=0.0001, score=0.561252 -   3.1s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] ..................... C=10, gamma=0.0001, score=0.568297 -   2.7s
# [CV] C=100, gamma=1 ..................................................
# [CV] ......................... C=100, gamma=1, score=0.502153 -   3.4s
# [CV] C=100, gamma=1 ..................................................
# [CV] ......................... C=100, gamma=1, score=0.504110 -   2.7s
# [CV] C=100, gamma=1 ..................................................
# [CV] ......................... C=100, gamma=1, score=0.504892 -   2.4s
# [CV] C=100, gamma=0.1 ................................................
# [CV] ....................... C=100, gamma=0.1, score=0.504501 -   2.6s
# [CV] C=100, gamma=0.1 ................................................
# [CV] ....................... C=100, gamma=0.1, score=0.504892 -   2.7s
# [CV] C=100, gamma=0.1 ................................................
# [CV] ....................... C=100, gamma=0.1, score=0.506458 -   2.5s
# [CV] C=100, gamma=0.01 ...............................................
# [CV] ...................... C=100, gamma=0.01, score=0.513112 -   2.5s
# [CV] C=100, gamma=0.01 ...............................................
# [CV] ...................... C=100, gamma=0.01, score=0.513503 -   2.5s
# [CV] C=100, gamma=0.01 ...............................................
# [CV] ...................... C=100, gamma=0.01, score=0.517417 -   2.5s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] ..................... C=100, gamma=0.001, score=0.533855 -   2.7s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] ..................... C=100, gamma=0.001, score=0.528767 -   2.6s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] ..................... C=100, gamma=0.001, score=0.538552 -   2.6s
# [CV] C=100, gamma=0.0001 .............................................
# [CV] .................... C=100, gamma=0.0001, score=0.564775 -   3.0s
# [CV] C=100, gamma=0.0001 .............................................
# [CV] .................... C=100, gamma=0.0001, score=0.561252 -   2.6s
# [CV] C=100, gamma=0.0001 .............................................
# [CV] .................... C=100, gamma=0.0001, score=0.568297 -   2.6s
# [CV] C=1000, gamma=1 .................................................
# [CV] ........................ C=1000, gamma=1, score=0.502153 -   2.8s
# [CV] C=1000, gamma=1 .................................................
# [CV] ........................ C=1000, gamma=1, score=0.504110 -   2.5s
# [CV] C=1000, gamma=1 .................................................
# [CV] ........................ C=1000, gamma=1, score=0.504892 -   2.4s
# [CV] C=1000, gamma=0.1 ...............................................
# [CV] ...................... C=1000, gamma=0.1, score=0.504501 -   2.6s
# [CV] C=1000, gamma=0.1 ...............................................
# [CV] ...................... C=1000, gamma=0.1, score=0.504892 -   3.0s
# [CV] C=1000, gamma=0.1 ...............................................
# [CV] ...................... C=1000, gamma=0.1, score=0.506458 -   2.8s
# [CV] C=1000, gamma=0.01 ..............................................
# [CV] ..................... C=1000, gamma=0.01, score=0.513112 -   3.0s
# [CV] C=1000, gamma=0.01 ..............................................
# [CV] ..................... C=1000, gamma=0.01, score=0.513503 -   3.0s
# [CV] C=1000, gamma=0.01 ..............................................
# [CV] ..................... C=1000, gamma=0.01, score=0.517417 -   2.6s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] .................... C=1000, gamma=0.001, score=0.533855 -   2.7s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] .................... C=1000, gamma=0.001, score=0.528767 -   2.6s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] .................... C=1000, gamma=0.001, score=0.538552 -   2.6s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................... C=1000, gamma=0.0001, score=0.564775 -   2.8s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................... C=1000, gamma=0.0001, score=0.561252 -   2.8s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................... C=1000, gamma=0.0001, score=0.568297 -   2.9s
# [Parallel(n_jobs=1)]: Done  75 out of  75 | elapsed:  3.4min finished
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ......................... C=0.1, gamma=1, score=0.501565 -   2.6s
# [CV] C=0.1, gamma=1 ..................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.6s remaining:    0.0s
# [CV] ......................... C=0.1, gamma=1, score=0.501761 -   2.4s
# [CV] C=0.1, gamma=1 ..................................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.1s remaining:    0.0s
# [CV] ......................... C=0.1, gamma=1, score=0.501761 -   2.4s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ....................... C=0.1, gamma=0.1, score=0.501565 -   2.3s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ....................... C=0.1, gamma=0.1, score=0.501761 -   2.3s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ....................... C=0.1, gamma=0.1, score=0.501761 -   2.3s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ...................... C=0.1, gamma=0.01, score=0.501565 -   2.4s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ...................... C=0.1, gamma=0.01, score=0.501761 -   2.4s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ...................... C=0.1, gamma=0.01, score=0.501761 -   2.4s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] ..................... C=0.1, gamma=0.001, score=0.501565 -   2.4s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] ..................... C=0.1, gamma=0.001, score=0.501761 -   2.4s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] ..................... C=0.1, gamma=0.001, score=0.501761 -   2.4s
# [CV] C=0.1, gamma=0.0001 .............................................
# [CV] .................... C=0.1, gamma=0.0001, score=0.501565 -   2.4s
# [CV] C=0.1, gamma=0.0001 .............................................
# [CV] .................... C=0.1, gamma=0.0001, score=0.501761 -   2.3s
# [CV] C=0.1, gamma=0.0001 .............................................
# [CV] .................... C=0.1, gamma=0.0001, score=0.501761 -   2.4s
# [CV] C=1, gamma=1 ....................................................
# [CV] ........................... C=1, gamma=1, score=0.501565 -   2.5s
# [CV] C=1, gamma=1 ....................................................
# [CV] ........................... C=1, gamma=1, score=0.501761 -   2.4s
# [CV] C=1, gamma=1 ....................................................
# [CV] ........................... C=1, gamma=1, score=0.501761 -   2.5s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ......................... C=1, gamma=0.1, score=0.505086 -   2.5s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ......................... C=1, gamma=0.1, score=0.505284 -   2.5s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ......................... C=1, gamma=0.1, score=0.501761 -   2.5s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........................ C=1, gamma=0.01, score=0.511737 -   2.5s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........................ C=1, gamma=0.01, score=0.512329 -   2.5s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........................ C=1, gamma=0.01, score=0.515068 -   2.5s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....................... C=1, gamma=0.001, score=0.524257 -   2.6s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....................... C=1, gamma=0.001, score=0.525636 -   2.6s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....................... C=1, gamma=0.001, score=0.531507 -   2.6s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ...................... C=1, gamma=0.0001, score=0.557512 -   2.7s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ...................... C=1, gamma=0.0001, score=0.555773 -   2.6s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ...................... C=1, gamma=0.0001, score=0.562427 -   2.6s
# [CV] C=10, gamma=1 ...................................................
# [CV] .......................... C=10, gamma=1, score=0.501565 -   2.4s
# [CV] C=10, gamma=1 ...................................................
# [CV] .......................... C=10, gamma=1, score=0.501761 -   2.4s
# [CV] C=10, gamma=1 ...................................................
# [CV] .......................... C=10, gamma=1, score=0.501761 -   2.5s
# [CV] C=10, gamma=0.1 .................................................
# [CV] ........................ C=10, gamma=0.1, score=0.505477 -   2.5s
# [CV] C=10, gamma=0.1 .................................................
# [CV] ........................ C=10, gamma=0.1, score=0.505675 -   2.5s
# [CV] C=10, gamma=0.1 .................................................
# [CV] ........................ C=10, gamma=0.1, score=0.501761 -   2.5s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....................... C=10, gamma=0.01, score=0.512520 -   2.5s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....................... C=10, gamma=0.01, score=0.512329 -   2.6s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....................... C=10, gamma=0.01, score=0.515068 -   2.5s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...................... C=10, gamma=0.001, score=0.524648 -   2.6s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...................... C=10, gamma=0.001, score=0.526810 -   2.6s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...................... C=10, gamma=0.001, score=0.532681 -   2.6s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] ..................... C=10, gamma=0.0001, score=0.561424 -   2.7s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] ..................... C=10, gamma=0.0001, score=0.559295 -   2.7s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] ..................... C=10, gamma=0.0001, score=0.567515 -   2.7s
# [CV] C=100, gamma=1 ..................................................
# [CV] ......................... C=100, gamma=1, score=0.501565 -   2.5s
# [CV] C=100, gamma=1 ..................................................
# [CV] ......................... C=100, gamma=1, score=0.501761 -   2.4s
# [CV] C=100, gamma=1 ..................................................
# [CV] ......................... C=100, gamma=1, score=0.501761 -   2.7s
# [CV] C=100, gamma=0.1 ................................................
# [CV] ....................... C=100, gamma=0.1, score=0.505477 -   2.6s
# [CV] C=100, gamma=0.1 ................................................
# [CV] ....................... C=100, gamma=0.1, score=0.505675 -   2.5s
# [CV] C=100, gamma=0.1 ................................................
# [CV] ....................... C=100, gamma=0.1, score=0.501761 -   2.5s
# [CV] C=100, gamma=0.01 ...............................................
# [CV] ...................... C=100, gamma=0.01, score=0.512520 -   2.6s
# [CV] C=100, gamma=0.01 ...............................................
# [CV] ...................... C=100, gamma=0.01, score=0.512329 -   2.6s
# [CV] C=100, gamma=0.01 ...............................................
# [CV] ...................... C=100, gamma=0.01, score=0.515068 -   2.5s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] ..................... C=100, gamma=0.001, score=0.524648 -   2.6s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] ..................... C=100, gamma=0.001, score=0.526810 -   2.6s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] ..................... C=100, gamma=0.001, score=0.532681 -   2.6s
# [CV] C=100, gamma=0.0001 .............................................
# [CV] .................... C=100, gamma=0.0001, score=0.561424 -   2.7s
# [CV] C=100, gamma=0.0001 .............................................
# [CV] .................... C=100, gamma=0.0001, score=0.559295 -   2.6s
# [CV] C=100, gamma=0.0001 .............................................
# [CV] .................... C=100, gamma=0.0001, score=0.567515 -   2.6s
# [CV] C=1000, gamma=1 .................................................
# [CV] ........................ C=1000, gamma=1, score=0.501565 -   2.5s
# [CV] C=1000, gamma=1 .................................................
# [CV] ........................ C=1000, gamma=1, score=0.501761 -   2.4s
# [CV] C=1000, gamma=1 .................................................
# [CV] ........................ C=1000, gamma=1, score=0.501761 -   2.5s
# [CV] C=1000, gamma=0.1 ...............................................
# [CV] ...................... C=1000, gamma=0.1, score=0.505477 -   2.5s
# [CV] C=1000, gamma=0.1 ...............................................
# [CV] ...................... C=1000, gamma=0.1, score=0.505675 -   2.6s
# [CV] C=1000, gamma=0.1 ...............................................
# [CV] ...................... C=1000, gamma=0.1, score=0.501761 -   2.5s
# [CV] C=1000, gamma=0.01 ..............................................
# [CV] ..................... C=1000, gamma=0.01, score=0.512520 -   2.5s
# [CV] C=1000, gamma=0.01 ..............................................
# [CV] ..................... C=1000, gamma=0.01, score=0.512329 -   2.6s
# [CV] C=1000, gamma=0.01 ..............................................
# [CV] ..................... C=1000, gamma=0.01, score=0.515068 -   2.5s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] .................... C=1000, gamma=0.001, score=0.524648 -   2.6s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] .................... C=1000, gamma=0.001, score=0.526810 -   2.6s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] .................... C=1000, gamma=0.001, score=0.532681 -   2.6s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................... C=1000, gamma=0.0001, score=0.561424 -   2.7s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................... C=1000, gamma=0.0001, score=0.559295 -   2.7s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................... C=1000, gamma=0.0001, score=0.567515 -   2.6s
# [Parallel(n_jobs=1)]: Done  75 out of  75 | elapsed:  3.3min finished
# 0.5788836634791333

# %%
#We find that SVM has very low accuracy,even by using GridSearch hence we discard this model.

# %%
# We finally find that the 'Decision Tree' or the 'Random Forest Classifier' model has the best accuracy. zHence we choose it.
